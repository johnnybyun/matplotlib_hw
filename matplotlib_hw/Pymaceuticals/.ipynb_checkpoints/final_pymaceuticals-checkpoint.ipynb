# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_df = pd.read_csv(mouse_drug_data_to_load, encoding="ISO-8859-1")
clinical_trial_df = pd.read_csv(clinical_trial_data_to_load, encoding="ISO-8859-1")

# %%
mouse_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
clinical_trial_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Check for bad data in the mouse data set. Looks good. 
mouse_df.count()
# Out:
# Mouse ID    250
# Drug        250
# dtype: int64

# %%
# Look for bad data in the clinical trial data set.  Looks good. 
clinical_trial_df.count()
# Out:
# Mouse ID              1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# dtype: int64

# %%
# Merge the two tables on 'Mouse ID' and look for any bad data.  
merge_table = pd.merge(mouse_df, clinical_trial_df, on="Mouse ID", how="left")
merge_table.count()
# The merge has increased the number of rows 1893 to 1906 which may indicate a duplicate.
# Out:
# Mouse ID              1906
# Drug                  1906
# Timepoint             1906
# Tumor Volume (mm3)    1906
# Metastatic Sites      1906
# dtype: int64

# %%
# We look for the duplicate. 
mouse_group = mouse_df.groupby(['Mouse ID'])
mouse_group.count().sort_values("Drug", ascending=False)
# g989 is associated with 2 drugs.
# Out:
#           Drug
# Mouse ID
# g989         2
# a203         1
# s121         1
# q597         1
# q610         1
# ...        ...
# j246         1
# j296         1
# j365         1
# j755         1
# z969         1
#
# [249 rows x 1 columns]

# %%
# Take a closer look at the g989 data.
g989 = merge_table.loc[merge_table["Mouse ID"]=="g989", :]
g989
# g989 is associated with two drugs.
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 41       g989  Stelasyn          0           45.000000                 0
# 42       g989  Stelasyn          0           45.000000                 0
# 43       g989  Stelasyn          5           48.786801                 0
# 44       g989  Stelasyn          5           47.570392                 0
# 45       g989  Stelasyn         10           51.745156                 0
# 46       g989  Stelasyn         10           49.880528                 0
# 47       g989  Stelasyn         15           51.325852                 1
# 48       g989  Stelasyn         15           53.442020                 0
# 49       g989  Stelasyn         20           55.326122                 1
# 50       g989  Stelasyn         20           54.657650                 1
# 51       g989  Stelasyn         25           56.045564                 1
# 52       g989  Stelasyn         30           59.082294                 1
# ...

# %%
# The 'g989' data is questionable so we drop it. 
new_merge = merge_table.drop(merge_table[(merge_table['Mouse ID'] == 'g989')].index)
new_merge.count()
# Confirm that the rows have been dropped.
# Out:
# Mouse ID              1880
# Drug                  1880
# Timepoint             1880
# Tumor Volume (mm3)    1880
# Metastatic Sites      1880
# dtype: int64

# %%
new_merge.head()
dfa = new_merge['Mouse ID']

# %%
# Rearrange the columns to match the output in the readme. 
merged_table = merge_table[['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites', 'Drug']]
merged_table.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites      Drug
# 0     f234          0           45.000000                 0  Stelasyn
# 1     f234          5           47.313491                 0  Stelasyn
# 2     f234         10           47.904324                 0  Stelasyn
# 3     f234         15           48.735197                 1  Stelasyn
# 4     f234         20           51.112713                 2  Stelasyn

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
grouped_table_m = merge_table.groupby(['Drug', 'Timepoint']).mean()

# Convert to DataFrame
# mean_tumor_df = grouped_table_m.reset_index()[['Drug', 'Timepoint', 'Tumor Volume (mm3)']]
mean_tumor_df = grouped_table_m.reset_index()[['Drug', 'Timepoint', 'Tumor Volume (mm3)']]

# Preview DataFrame
mean_tumor_df
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# MEAN TUMOR:  Minor Data Munging to Re-Format the Mean Tumor Data Frame
new_mean_tumor_df = mean_tumor_df.pivot(index='Timepoint', columns='Drug',values='Tumor Volume (mm3)')
new_mean_tumor_df
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
grouped_table_sem = merge_table.groupby(['Drug', 'Timepoint']).sem()
# Convert to DataFrame
sem_tumor_df = grouped_table_sem.reset_index()[['Drug', 'Timepoint', 'Tumor Volume (mm3)']]
# Preview DataFrame
sem_tumor_df
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
# SEM: Minor Data Munging to Re-Format the SEM Data Frame
new_sem_tumor_df = sem_tumor_df.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
new_sem_tumor_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot 

plt.errorbar(new_mean_tumor_df.index, 
             new_mean_tumor_df['Capomulin'], 
             yerr=new_sem_tumor_df['Capomulin'], 
             marker='o', color='red', linewidth=0.5)

plt.errorbar(new_mean_tumor_df.index, 
             new_mean_tumor_df['Infubinol'], 
             yerr=new_sem_tumor_df['Infubinol'], 
             marker='o', color='blue', linewidth=0.5)

plt.errorbar(new_mean_tumor_df.index, 
             new_mean_tumor_df['Ketapril'], 
             yerr=new_sem_tumor_df['Ketapril'], 
             marker='o', color='green', linewidth=0.5)

plt.errorbar(new_mean_tumor_df.index, 
             new_mean_tumor_df['Placebo'], 
             yerr=new_sem_tumor_df['Placebo'], 
             marker='o', color='black', linewidth=0.5)

Capomulin, = plt.plot(new_mean_tumor_df.index, 
                     new_mean_tumor_df['Capomulin'], 
                     marker='o', color='red', label='Capomulin')

Infubinol, = plt.plot(new_mean_tumor_df.index, 
                     new_mean_tumor_df['Infubinol'], 
                     marker='o', color='blue', label='Infubinol')

Ketapril, = plt.plot(new_mean_tumor_df.index, 
                     new_mean_tumor_df['Ketapril'], 
                     marker='o', color='green', label='Ketapril')

Placebo, = plt.plot(new_mean_tumor_df.index, 
                     new_mean_tumor_df['Placebo'], 
                     marker='o', color='black', label='Placebo')

plt.xlabel('Time (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Tumor Response to Treatment')
plt.grid(axis='y')
plt.legend(loc='best')
plt.savefig('../Images/treatment.png')
plt.show()

# %%
## METASTATIC SITE: Store the Mean Metastatic Site Data Grouped by Drug and Timepoint 
mean_metastatic_df = grouped_table_m.reset_index()[['Drug', 'Timepoint', 'Metastatic Sites']]
mean_metastatic_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# ..        ...        ...               ...
# 95  Zoniferol         25          1.687500
# 96  Zoniferol         30          1.933333
# 97  Zoniferol         35          2.285714
# 98  Zoniferol         40          2.785714
# 99  Zoniferol         45          3.071429
#
# [100 rows x 3 columns]

# %%
new_mean_metastatic_df = mean_metastatic_df.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')
new_mean_metastatic_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Store the Standard Error of Metastatic Sites Grouped by Drug and Timepoint
grouped_table_sem = merge_table.groupby(['Drug', 'Timepoint']).sem()
# Convert to DataFrame
sem_metastatic_df = grouped_table_sem.reset_index()[['Drug', 'Timepoint', 'Metastatic Sites']]
# Preview DataFrame
sem_metastatic_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
new_sem_metastatic_df = sem_metastatic_df.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')
new_sem_metastatic_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.errorbar(new_mean_metastatic_df.index, 
             new_mean_metastatic_df['Capomulin'], 
             yerr=new_sem_metastatic_df['Capomulin'], 
             marker='o', color='r', linewidth=0.5)

plt.errorbar(new_mean_metastatic_df.index, 
             new_mean_metastatic_df['Infubinol'], 
             yerr=new_sem_metastatic_df['Infubinol'], 
             marker='o', color='b', linewidth=0.5)

plt.errorbar(new_mean_metastatic_df.index, 
             new_mean_metastatic_df['Ketapril'], 
             yerr=new_sem_metastatic_df['Ketapril'], 
             marker='o', color='g', linewidth=0.5)

plt.errorbar(new_mean_metastatic_df.index, 
             new_mean_metastatic_df['Placebo'], 
             yerr=new_sem_metastatic_df['Placebo'], 
             marker='o', color='k', linewidth=0.5)

Capomulin, = plt.plot(new_mean_metastatic_df.index, 
                     new_mean_metastatic_df['Capomulin'], 
                     marker='o', color='red', label='Capomulin')

Infubinol, = plt.plot(new_mean_metastatic_df.index, 
                     new_mean_metastatic_df['Infubinol'], 
                     marker='o', color='blue', label='Infubinol')

Ketapril, = plt.plot(new_mean_metastatic_df.index, 
                     new_mean_metastatic_df['Ketapril'], 
                     marker='o', color='green', label='Ketapril')

Placebo, = plt.plot(new_mean_metastatic_df.index, 
                     new_mean_metastatic_df['Placebo'], 
                     marker='o', color='black', label='Placebo')


plt.xlabel('Treatment Duration (Days)')
plt.ylabel('Met. Sites')
plt.title('Metastatic Spread During Treatment')
plt.grid(axis='y')
plt.legend(loc='upper left')

plt.savefig('../Images/spread.png')
plt.show()

# %%
# Store the Mouse Count 
grouped_table_c = merge_table.groupby(['Drug', 'Timepoint']).count()
count_mouse_df = grouped_table_c.reset_index()[['Drug', 'Timepoint', 'Mouse ID']]
count_mouse_df
# Out:
#          Drug  Timepoint  Mouse ID
# 0   Capomulin          0        25
# 1   Capomulin          5        25
# 2   Capomulin         10        25
# 3   Capomulin         15        24
# 4   Capomulin         20        23
# ..        ...        ...       ...
# 95  Zoniferol         25        16
# 96  Zoniferol         30        15
# 97  Zoniferol         35        14
# 98  Zoniferol         40        14
# 99  Zoniferol         45        14
#
# [100 rows x 3 columns]

# %%
new_count_mouse_df = count_mouse_df.pivot(index='Timepoint', columns='Drug', values='Mouse ID')
new_count_mouse_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
plt.errorbar(new_count_mouse_df.index, 
             (new_count_mouse_df['Capomulin']/new_count_mouse_df.loc[0, "Capomulin"])*100, 
             yerr=0, 
             marker='o', color='red', linewidth=0.5)

plt.errorbar(new_count_mouse_df.index, 
             (new_count_mouse_df['Infubinol']/new_count_mouse_df.loc[0, "Infubinol"])*100, 
             yerr=0, 
             marker='o', color='blue', linewidth=0.5)

plt.errorbar(new_count_mouse_df.index, 
             (new_count_mouse_df['Ketapril']/new_count_mouse_df.loc[0, "Ketapril"])*100, 
             yerr=0, 
             marker='o', color='green', linewidth=0.5)

plt.errorbar(new_count_mouse_df.index, 
             (new_count_mouse_df['Placebo']/new_count_mouse_df.loc[0, "Placebo"])*100, 
             yerr=0, 
             marker='o', color='black', linewidth=0.5)

Capomulin, = plt.plot(new_count_mouse_df.index, 
                     (new_count_mouse_df['Capomulin']/new_count_mouse_df.loc[0, "Capomulin"])*100, 
                     marker='o', color='red', label='Capomulin')

Infubinol, = plt.plot(new_count_mouse_df.index, 
                     (new_count_mouse_df['Infubinol']/new_count_mouse_df.loc[0, "Infubinol"])*100, 
                      marker='o', color='blue', label='Ketapril')

Ketapril, = plt.plot(new_count_mouse_df.index, 
                     (new_count_mouse_df['Ketapril']/new_count_mouse_df.loc[0, "Ketapril"])*100, 
                     marker='o', color='green', label='Ketapril')

Placebo, = plt.plot(new_count_mouse_df.index, 
                     (new_count_mouse_df['Placebo']/new_count_mouse_df.loc[0, "Placebo"])*100, 
                     marker='o', color='black', label='Placebo')

plt.xlabel('Time (Days)')
plt.ylabel('Survival Rate (%)')
plt.title('Survival During Treatment')
plt.grid(axis='y')
plt.legend(loc='best')
plt.savefig('../Images/survival.png')
plt.show()

# %%
new_mean_tumor_df
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
total_pct_chg_tumor_vol = ((new_mean_tumor_df.loc[45,:]-new_mean_tumor_df.loc[0,:])/new_mean_tumor_df.loc[0,:])*100
total_pct_chg_tumor_vol
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
x_tuple = ('Capomulin', 'Infubinol', 'Ketapril', 'Placebo')
y_tuple = (total_pct_chg_tumor_vol['Capomulin'], 
           total_pct_chg_tumor_vol['Infubinol'], 
           total_pct_chg_tumor_vol['Ketapril'], 
           total_pct_chg_tumor_vol['Placebo'])
y_tuple
# Out:
# (-19.475302667894173, 46.12347172785187, 57.028794686606076, 51.29796048315153)

# %%
plt.bar(x_tuple, y_tuple, width=-1, color=["green", "red", "red", "red"], edgecolor="grey", align="edge")
plt.grid(axis='y')
plt.grid(axis='x')
plt.title('Tumor Change Over 45 Day Treatment')
plt.ylabel('% Tumor Volume Change')
plt.savefig('../Images/change.png')
plt.show()
